# %%
import os 
import sys
import time

paths_to_add = [
    os.path.abspath(os.path.join('../..')),  
    os.path.abspath(os.path.join('..'))  
]

sys.path.extend(path for path in paths_to_add if path not in sys.path)

# %%
import jax
from jax import jit, vmap
import jax.numpy as jnp
import numpy as np
import scipy.stats
from jax import random
import matplotlib.pyplot as plt

from fbpinns import networks
from fbpinns.domains import RectangularDomainND
from fbpinns.decompositions import RectangularDecompositionND
from fbpinns.networks import FCN
from fbpinns.schedulers import LineSchedulerRectangularND, AllActiveSchedulerND
from fbpinns.constants import Constants, get_subdomain_ws
from fbpinns.trainers import FBPINNTrainer

from cooksDomain import CooksDomainND
from CooksMembrane.cooksProblem import CooksProblemForwardHardVersion2, CooksProblemForwardHard

# %%
# step 1: Domain
corners = jnp.array([(0., 0.), (0, 0.044), (0.048, 0.060), (0.048, 0.044)]) 
domain = CooksDomainND
domain_init_kwargs = dict(
    corners=corners,
)
domain_init_kwargs

# Example 2D Plot
key = jax.random.PRNGKey(0)
all_params = {
    "static": {
        "domain": {
            "xd": 2,
            "corners": corners,
        }
    }
}

batch_shape = (10,20)  # for example
x_batch = domain.sample_interior(all_params, key, 'uniform', batch_shape)

batch_shapes = ((20,),(15,),(10,),(10,)) # bottom, top, left, right
x_boundaries = domain.sample_boundaries(all_params, key, 'sobol', batch_shapes)

plt.scatter(x_batch[:, 0:1], x_batch[:, 1:2])
for x_batch_b in x_boundaries:
        plt.scatter(x_batch_b[:,0], x_batch_b[:,1], )
# Out:
# c:\Users\tirth\anaconda3\envs\fbpinns\Lib\site-packages\scipy\stats\_qmc.py:958: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)

# %%
print(x_batch.shape, len(x_boundaries), x_boundaries[0].shape)
final_batch = jnp.vstack([x_batch] + x_boundaries)
print(final_batch.shape)
# Out:
# (200, 2) 4 (20, 2)
# (255, 2)

# %%
# step 2: prbolem
# problem = CooksProblemForwardSoft
problem = CooksProblemForwardHardVersion2
problem_init_kwargs = dict(lambda_true= 4, mu_true = 5, 
                    nbc_points_right = 200, nbc_points_top=200, 
                    nbc_points_bottom=200, dbc_points_left=200, sd=0.1)
problem_init_kwargs
# Out:
# {'lambda_true': 4,
#  'mu_true': 5,
#  'nbc_points_right': 200,
#  'nbc_points_top': 200,
#  'nbc_points_bottom': 200,
#  'dbc_points_left': 200,
#  'sd': 0.1}

# %%
# step 3: decompostion
decomposition = RectangularDecompositionND
nsub = [2,2]
wo = 1.6
subdomain_xs = [np.linspace(0,0.048,nsub[0]), np.linspace(0,0.060,nsub[1])]
subdomain_xs = [[0.012, 0.034], [0.022, 0.052]]
subdomain_ws=get_subdomain_ws(subdomain_xs, wo)
decomposition_init_kwargs = dict(
    subdomain_xs=subdomain_xs,
    subdomain_ws=get_subdomain_ws(subdomain_xs, wo),
    unnorm=(0.,1.),
)
print(decomposition_init_kwargs)

# plot 2D
ps_ = decomposition.init_params(subdomain_xs, subdomain_ws, (0,3))
all_params = {"static":{"decomposition":ps_[0]}, "trainable":{"decomposition":ps_[1]}}
m = all_params["static"]["decomposition"]["m"]
active = np.ones(m)

# active[1] = 0
active[2] = 2
decomposition.plot(all_params, active=active, show_norm=True, show_window=True)

# for x in x_batch:
#     plt.scatter(x[0], x[1])
plt.scatter(x_batch[:, 0:1], x_batch[:, 1:2])
for x_batch_b in x_boundaries:
        plt.scatter(x_batch_b[:,0], x_batch_b[:,1], )
plt.show()
# Out:
# {'subdomain_xs': [[0.012, 0.034], [0.022, 0.052]], 'subdomain_ws': [array([0.0352, 0.0352]), array([0.048, 0.048])], 'unnorm': (0.0, 1.0)}

# %%
# tolerence check! Just to consider certain boundary poins
tolerence = 1e-6
for x_batch_b in x_boundaries:
    x, y = x_batch_b[:,0:1], x_batch_b[:,1:2]
    m_top = (0.06 -0.044) / (0.048 -0)
    b_top = 0.044                       # Create the line
    y_on_the_top = (jnp.abs(y-(m_top * x + b_top)) < tolerence) & (x>=0) & (x<=0.048) # replace >= and <= in main code
    if y_on_the_top.any():
        plt.scatter(x,y)
plt.show()

# %%
# Test the tolerence for applying Hard BC on the problem, if plots: Danger!
tolerence=1e-6
x, y = x_batch[:,0:1], x_batch[:,1:2]
m_top = (0.06 -0.044) / (0.048 -0)
b_top = 0.044                       # Create the line
y_on_the_top = (jnp.abs(y-(m_top * x + b_top)) < tolerence) & (x>=0) & (x<=0.048) # replace >= and <= in main code
if y_on_the_top.any():
    plt.scatter(x,y)
plt.show()

# %%
# step 4: network
network=FCN
network_init_kwargs = dict(
    layer_sizes = (2, 16, 5),
)

# %%
# step 5 scheduler # try with all active together
# scheduler = AllActiveSchedulerND
# scheduler_kwargs = dict()
scheduler = LineSchedulerRectangularND
scheduler_kwargs = dict(
    point=[0.], iaxis=0,
)

# %%
tag = "adaptive"
nc = (30,30)
epochs = 30000
h = len(network_init_kwargs["layer_sizes"]) - 2
p = sum(network_init_kwargs["layer_sizes"][1:-1])
run = f"FBPINN_{tag}_{problem.__name__}_{network.__name__}_{nc}-nCol_{epochs}-e_{h}-l_{p}-h_{wo}-wo_{LineSchedulerRectangularND.__name__}_{nsub}-nsub_"
run
# Out:
# 'FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_'

# %%
from fbpinns.constants import Constants

c = Constants(
    run=run,
    domain=domain,
    domain_init_kwargs=domain_init_kwargs,
    problem=problem,
    problem_init_kwargs=problem_init_kwargs,
    decomposition=decomposition,
    decomposition_init_kwargs=decomposition_init_kwargs,
    network=network,
    network_init_kwargs=network_init_kwargs,
    scheduler=scheduler,
    scheduler_kwargs=scheduler_kwargs,
    ns=(nc,),# use 200 collocation points for training
    n_test=(50,50),# use 500 points for testing
    n_steps=epochs,# number of training steps
    clear_output=True,
    show_figures=False,
    test_freq=150000,
    skip_plot_at_first=True,
)
print(c)
# Out:
# <fbpinns.constants.Constants object at 0x000001FF8516E690>
# run: FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# domain: <class 'cooksDomain.CooksDomainND'>
# domain_init_kwargs: {'corners': Array([[0.   , 0.   ],
#        [0.   , 0.044],
#        [0.048, 0.06 ],
#        [0.048, 0.044]], dtype=float32)}
# problem: <class 'CooksMembrane.cooksProblem.CooksProblemForwardHardVersion2'>
# problem_init_kwargs: {'lambda_true': 4, 'mu_true': 5, 'nbc_points_right': 200, 'nbc_points_top': 200, 'nbc_points_bottom': 200, 'dbc_points_left': 200, 'sd': 0.1}
# decomposition: <class 'fbpinns.decompositions.RectangularDecompositionND'>
# decomposition_init_kwargs: {'subdomain_xs': [[0.012, 0.034], [0.022, 0.052]], 'subdomain_ws': [array([0.0352, 0.0352]), array([0.048, 0.048])], 'unnorm': (0.0, 1.0)}
# network: <class 'fbpinns.networks.FCN'>
# network_init_kwargs: {'layer_sizes': (2, 16, 5)}
# n_steps: 30000
# scheduler: <class 'fbpinns.schedulers.LineSchedulerRectangularND'>
# scheduler_kwargs: {'point': [0.0], 'iaxis': 0}
# ns: ((30, 30),)
# n_test: (50, 50)
# sampler: grid
# optimiser: <function adam at 0x000001FF804694E0>
# optimiser_kwargs: {'learning_rate': 0.001}
# seed: 0
# summary_freq: 1000
# test_freq: 150000
# model_save_freq: 10000
# show_figures: False
# save_figures: False
# clear_output: True
# hostname: ts
# skip_plot_at_first: True

# %%
training_time = time.time()
FBPINNrun = FBPINNTrainer(c)
FBPINNrun.train()

training_time = time.time() - training_time
print(training_time)
# Out:
# [INFO] 2024-03-26 10:46:57 - <fbpinns.constants.Constants object at 0x000001FF8516E690>
# run: FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# domain: <class 'cooksDomain.CooksDomainND'>
# domain_init_kwargs: {'corners': Array([[0.   , 0.   ],
#        [0.   , 0.044],
#        [0.048, 0.06 ],
#        [0.048, 0.044]], dtype=float32)}
# problem: <class 'CooksMembrane.cooksProblem.CooksProblemForwardHardVersion2'>
# problem_init_kwargs: {'lambda_true': 4, 'mu_true': 5, 'nbc_points_right': 200, 'nbc_points_top': 200, 'nbc_points_bottom': 200, 'dbc_points_left': 200, 'sd': 0.1}
# decomposition: <class 'fbpinns.decompositions.RectangularDecompositionND'>
# decomposition_init_kwargs: {'subdomain_xs': [[0.012, 0.034], [0.022, 0.052]], 'subdomain_ws': [array([0.0352, 0.0352]), array([0.048, 0.048])], 'unnorm': (0.0, 1.0)}
# network: <class 'fbpinns.networks.FCN'>
# network_init_kwargs: {'layer_sizes': (2, 16, 5)}
# n_steps: 30000
# scheduler: <class 'fbpinns.schedulers.LineSchedulerRectangularND'>
# scheduler_kwargs: {'point': [0.0], 'iaxis': 0}
# ns: ((30, 30),)
# n_test: (50, 50)
# sampler: grid
# optimiser: <function adam at 0x000001FF804694E0>
# optimiser_kwargs: {'learning_rate': 0.001}
# seed: 0
# summary_freq: 1000
# test_freq: 150000
# model_save_freq: 10000
# show_figures: False
# save_figures: False
# clear_output: True
# hostname: ts
# skip_plot_at_first: True
#
# [INFO] 2024-03-26 10:46:58 - Total number of subdomains: 4
# [INFO] 2024-03-26 10:47:00 - Total number of trainable parameters:
# [INFO] 2024-03-26 10:47:00 - 	network: 532
# [INFO] 2024-03-26 10:47:02 - Total number of constraints: 1
# [INFO] 2024-03-26 10:47:02 - Computing exact solution..
# [INFO] 2024-03-26 10:47:03 - Computing done
# [INFO] 2024-03-26 10:47:03 - Getting test data inputs..
# [INFO] 2024-03-26 10:47:06 - [i: 0/30000] Updating active inputs..
# [INFO] 2024-03-26 10:47:07 - [i: 0/30000] Average number of points/dimension in active subdomains: 26.00
# [INFO] 2024-03-26 10:47:10 - [i: 0/30000] Updating active inputs done (3.39 s)
# [INFO] 2024-03-26 10:47:10 - [i: 0/30000] Compiling update step..
# [INFO] 2024-03-26 10:47:10 - x_batch
# [INFO] 2024-03-26 10:47:10 - (1102, 2), float32, JVPTracer
# [INFO] 2024-03-26 10:47:10 - x_take
# [INFO] 2024-03-26 10:47:10 - (2120, 2), float32, JVPTracer
# [INFO] 2024-03-26 10:47:10 - x_batch
# [INFO] 2024-03-26 10:47:10 - (1102, 2), float32, JVPTracer
# [INFO] 2024-03-26 10:47:10 - x_take
# [INFO] 2024-03-26 10:47:10 - (2120, 2), float32, JVPTracer
# [INFO] 2024-03-26 10:47:14 - [i: 0/30000] Compiling done (4.14 s)
# [INFO] 2024-03-26 10:47:32 - [i: 1000/30000] loss: 0.7848 rate: 41.2 elapsed: 0.01 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:47:47 - [i: 2000/30000] loss: 0.6177 rate: 63.5 elapsed: 0.01 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:48:03 - [i: 3000/30000] loss: 0.5563 rate: 62.7 elapsed: 0.02 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:48:20 - [i: 4000/30000] loss: 0.5144 rate: 61.1 elapsed: 0.02 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:48:37 - [i: 5000/30000] loss: 0.4767 rate: 59.1 elapsed: 0.03 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:48:53 - [i: 6000/30000] loss: 0.4404 rate: 61.8 elapsed: 0.03 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:49:08 - [i: 7000/30000] loss: 0.4023 rate: 64.4 elapsed: 0.03 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:49:24 - [i: 8000/30000] loss: 0.3594 rate: 64.5 elapsed: 0.04 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:49:39 - [i: 9000/30000] loss: 0.3195 rate: 64.8 elapsed: 0.04 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:49:55 - [i: 10000/30000] loss: 0.2786 rate: 62.9 elapsed: 0.05 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:50:11 - [i: 11000/30000] loss: 0.2340 rate: 61.4 elapsed: 0.05 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:50:28 - [i: 12000/30000] loss: 0.2087 rate: 60.7 elapsed: 0.06 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:50:44 - [i: 13000/30000] loss: 0.1969 rate: 62.8 elapsed: 0.06 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:51:00 - [i: 14000/30000] loss: 0.1844 rate: 61.6 elapsed: 0.07 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:51:15 - [i: 15000/30000] loss: 0.1773 rate: 67.7 elapsed: 0.07 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:51:15 - [i: 15000/30000] Updating active inputs..
# [INFO] 2024-03-26 10:51:15 - [i: 15000/30000] Average number of points/dimension in active subdomains: 27.07
# [INFO] 2024-03-26 10:51:17 - [i: 15000/30000] Updating active inputs done (2.51 s)
# [INFO] 2024-03-26 10:51:17 - [i: 15000/30000] Compiling update step..
# [INFO] 2024-03-26 10:51:17 - x_batch
# [INFO] 2024-03-26 10:51:17 - (1229, 2), float32, JVPTracer
# [INFO] 2024-03-26 10:51:17 - x_take
# [INFO] 2024-03-26 10:51:17 - (2234, 2), float32, JVPTracer
# [INFO] 2024-03-26 10:51:18 - x_batch
# [INFO] 2024-03-26 10:51:18 - (1229, 2), float32, JVPTracer
# [INFO] 2024-03-26 10:51:18 - x_take
# [INFO] 2024-03-26 10:51:18 - (2234, 2), float32, JVPTracer
# [INFO] 2024-03-26 10:51:21 - [i: 15000/30000] Compiling done (3.61 s)
# [INFO] 2024-03-26 10:51:50 - [i: 16000/30000] loss: 2.0818 rate: 28.1 elapsed: 0.08 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:52:17 - [i: 17000/30000] loss: 1.2727 rate: 37.7 elapsed: 0.09 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:52:48 - [i: 18000/30000] loss: 1.0480 rate: 31.8 elapsed: 0.10 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:53:20 - [i: 19000/30000] loss: 0.9477 rate: 31.3 elapsed: 0.10 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:53:52 - [i: 20000/30000] loss: 0.8905 rate: 31.8 elapsed: 0.11 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:54:24 - [i: 21000/30000] loss: 0.8537 rate: 31.5 elapsed: 0.12 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:54:56 - [i: 22000/30000] loss: 0.8258 rate: 32.1 elapsed: 0.13 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:55:29 - [i: 23000/30000] loss: 0.8031 rate: 29.7 elapsed: 0.14 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:56:02 - [i: 24000/30000] loss: 0.8179 rate: 30.8 elapsed: 0.15 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:56:32 - [i: 25000/30000] loss: 0.7706 rate: 32.5 elapsed: 0.16 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:57:03 - [i: 26000/30000] loss: 0.7609 rate: 32.9 elapsed: 0.17 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:57:33 - [i: 27000/30000] loss: 0.7530 rate: 32.9 elapsed: 0.17 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:58:04 - [i: 28000/30000] loss: 0.7452 rate: 32.6 elapsed: 0.18 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:58:30 - [i: 29000/30000] loss: 0.7402 rate: 37.7 elapsed: 0.19 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:58:46 - [i: 30000/30000] loss: 0.7335 rate: 64.2 elapsed: 0.19 hr FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_
# [INFO] 2024-03-26 10:58:46 - [i: 30000/30000] Training complete
# 708.6994650363922

# %%
from FBPINNsModel.plot import load_FBPINN, load_PINN, exact_solution
from fbpinns.analysis import load_model

# run = "test"
# load model
c, model = load_model(run, rootdir="results/")

# Test model
from fbpinns.analysis import FBPINN_solution, PINN_solution
i, all_params, all_opt_states, active, u_test_losses = model
x_batch_test = domain.sample_interior(all_params=all_params, key=None, sampler="grid", batch_shape=(500,500))
out = FBPINN_solution(c, all_params, active, x_batch_test)

ux_test, uy_test, sigaxx_test, sigmayy_test, sigmaxy_test  = out[:,0:1],out[:,1:2],out[:,2:3],out[:,3:4],out[:,4:5]
# Out:
# [INFO] 2024-03-26 10:58:47 - Loading model from:
# results/models/FBPINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-e_1-l_16-h_1.6-wo_LineSchedulerRectangularND_[2, 2]-nsub_/model_00030000.jax
# [INFO] 2024-03-26 10:58:51 - x_batch
# [INFO] 2024-03-26 10:58:51 - (250000, 2), float32, ArrayImpl
# [INFO] 2024-03-26 10:58:51 - x_take
# [INFO] 2024-03-26 10:58:51 - (482475, 2), float32, ArrayImpl

# %%
from CooksMembrane.util import plot_deformation

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6), dpi=300)
plot_deformation(ux_test, x_batch_test,ax1,"ux")
plot_deformation(uy_test, x_batch_test,ax2,"uy")
plt.tight_layout()
plt.show()

# %%
plot_deformation(sigmaxy_test, x_batch_test,ax1,"ux")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_deformation(sigmaxy_test, x_batch_test,ax1,"ux")
#
# NameError: name 'plot_deformation' is not defined

# %% [markdown]
# ### FBPINNs Vs FEM Comparision

# %%
import pandas as pd 

FEM = pd.read_csv("FEM_result/stats.csv")

FEM = FEM[['u:0', 'u:1', 'Points:0', 'Points:1']].rename(columns={'u:0': 'ux', 'u:1': 'uy', 'Points:0': 'x', 'Points:1': 'y'})

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6), dpi=300)
plot_deformation( FEM["ux"],FEM[['x', 'y']].values, ax1, "FEM ux", 16)

# NN sol
x_batch_test = FEM[['x', 'y']].values
out = FBPINN_solution(c, all_params, active, x_batch_test)

ux_test, uy_test, sigaxx_test, sigmayy_test, sigmaxy_test  = out[:,0:1],out[:,1:2],out[:,2:3],out[:,3:4],out[:,4:5]
plot_deformation(ux_test, x_batch_test, ax2, set_title="NN ux", point_size=16)
# Out:
# [INFO] 2024-03-26 10:59:11 - x_batch
# [INFO] 2024-03-26 10:59:11 - (121, 2), float64, ndarray
# [INFO] 2024-03-26 10:59:11 - x_take
# [INFO] 2024-03-26 10:59:11 - (230, 2), float64, ndarray

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6), dpi=300)
plot_deformation( FEM["uy"],FEM[['x', 'y']].values, ax1, "FEM uy", 16)
plot_deformation(uy_test, x_batch_test, ax2, set_title="NN uy", point_size=16)

# %% [markdown]
# ### Apply PINNTrainer to the Problem

# %%
run = f"PINN_{tag}_{problem.__name__}_{network.__name__}_{nc}-nCol_{epochs}-epochs_{h}-layers_{p}-hidden_{wo}_wo_"
run
# Out:
# 'PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_'

# %%
c = Constants(
    run=run,
    domain=domain,
    domain_init_kwargs=domain_init_kwargs,
    problem=problem,
    problem_init_kwargs=problem_init_kwargs,
    decomposition=decomposition,
    decomposition_init_kwargs=decomposition_init_kwargs,
    network=network,
    network_init_kwargs=network_init_kwargs,
    scheduler=scheduler,
    scheduler_kwargs=scheduler_kwargs,
    ns=(nc,),# use 200 collocation points for training
    n_test=(50,50),# use 500 points for testing
    n_steps=epochs,# number of training steps
    clear_output=True,
    show_figures=False,
    test_freq=100000,
    skip_plot_at_first=True,
)

from fbpinns.trainers import PINNTrainer

c["network_init_kwargs"] = dict(layer_sizes=[2,16, 16, 16,5]) # use a larger neural network

PINNrun = PINNTrainer(c)
PINNrun.train()
# Out:
# [INFO] 2024-03-26 10:59:15 - <fbpinns.constants.Constants object at 0x000001FF9FBB84D0>
# run: PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# domain: <class 'cooksDomain.CooksDomainND'>
# domain_init_kwargs: {'corners': Array([[0.   , 0.   ],
#        [0.   , 0.044],
#        [0.048, 0.06 ],
#        [0.048, 0.044]], dtype=float32)}
# problem: <class 'CooksMembrane.cooksProblem.CooksProblemForwardHardVersion2'>
# problem_init_kwargs: {'lambda_true': 4, 'mu_true': 5, 'nbc_points_right': 200, 'nbc_points_top': 200, 'nbc_points_bottom': 200, 'dbc_points_left': 200, 'sd': 0.1}
# decomposition: <class 'fbpinns.decompositions.RectangularDecompositionND'>
# decomposition_init_kwargs: {'subdomain_xs': [[0.012, 0.034], [0.022, 0.052]], 'subdomain_ws': [array([0.0352, 0.0352]), array([0.048, 0.048])], 'unnorm': (0.0, 1.0)}
# network: <class 'fbpinns.networks.FCN'>
# network_init_kwargs: {'layer_sizes': [2, 16, 16, 16, 5]}
# n_steps: 30000
# scheduler: <class 'fbpinns.schedulers.LineSchedulerRectangularND'>
# scheduler_kwargs: {'point': [0.0], 'iaxis': 0}
# ns: ((30, 30),)
# n_test: (50, 50)
# sampler: grid
# optimiser: <function adam at 0x000001FF804694E0>
# optimiser_kwargs: {'learning_rate': 0.001}
# seed: 0
# summary_freq: 1000
# test_freq: 100000
# model_save_freq: 10000
# show_figures: False
# save_figures: False
# clear_output: True
# hostname: ts
# skip_plot_at_first: True
#
# [INFO] 2024-03-26 10:59:16 - Total number of trainable parameters:
# [INFO] 2024-03-26 10:59:16 - 	network: 677
# [INFO] 2024-03-26 10:59:17 - Total number of constraints: 1
# [INFO] 2024-03-26 10:59:17 - Computing exact solution..
# [INFO] 2024-03-26 10:59:17 - Computing done
# [INFO] 2024-03-26 10:59:17 - [i: 0/30000] Compiling update step..
# [INFO] 2024-03-26 10:59:17 - x_batch
# [INFO] 2024-03-26 10:59:17 - (1700, 2), float32, JVPTracer
# [INFO] 2024-03-26 10:59:17 - x_batch
# [INFO] 2024-03-26 10:59:17 - (1700, 2), float32, JVPTracer
# [INFO] 2024-03-26 10:59:19 - [i: 0/30000] Compiling done (2.62 s)
# [INFO] 2024-03-26 10:59:44 - [i: 1000/30000] loss: 1.0990 rate: 40.9 elapsed: 0.01 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:00:06 - [i: 2000/30000] loss: 1.0981 rate: 44.7 elapsed: 0.01 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:00:35 - [i: 3000/30000] loss: 1.0976 rate: 35.6 elapsed: 0.02 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:01:09 - [i: 4000/30000] loss: 1.0963 rate: 29.3 elapsed: 0.03 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:01:37 - [i: 5000/30000] loss: 1.0869 rate: 34.7 elapsed: 0.04 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:02:02 - [i: 6000/30000] loss: 1.0678 rate: 40.5 elapsed: 0.05 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:02:27 - [i: 7000/30000] loss: 1.0487 rate: 41.0 elapsed: 0.05 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:02:57 - [i: 8000/30000] loss: 1.0353 rate: 33.1 elapsed: 0.06 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:03:37 - [i: 9000/30000] loss: 1.0261 rate: 24.8 elapsed: 0.07 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:04:02 - [i: 10000/30000] loss: 1.0153 rate: 40.0 elapsed: 0.08 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:04:26 - [i: 11000/30000] loss: 0.9991 rate: 42.5 elapsed: 0.09 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:04:51 - [i: 12000/30000] loss: 1.0043 rate: 38.9 elapsed: 0.09 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:05:14 - [i: 13000/30000] loss: 0.9763 rate: 43.4 elapsed: 0.10 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:05:36 - [i: 14000/30000] loss: 0.8763 rate: 46.3 elapsed: 0.10 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:05:58 - [i: 15000/30000] loss: 0.8230 rate: 45.8 elapsed: 0.11 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:06:23 - [i: 16000/30000] loss: 0.7633 rate: 40.5 elapsed: 0.12 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:06:44 - [i: 17000/30000] loss: 0.6909 rate: 46.7 elapsed: 0.12 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:07:06 - [i: 18000/30000] loss: 0.6282 rate: 46.5 elapsed: 0.13 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:07:27 - [i: 19000/30000] loss: 0.6085 rate: 46.5 elapsed: 0.14 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:07:49 - [i: 20000/30000] loss: 0.5508 rate: 45.9 elapsed: 0.14 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:08:11 - [i: 21000/30000] loss: 0.5287 rate: 45.9 elapsed: 0.15 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:08:32 - [i: 22000/30000] loss: 0.5143 rate: 46.7 elapsed: 0.15 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:08:53 - [i: 23000/30000] loss: 0.5048 rate: 47.1 elapsed: 0.16 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:09:15 - [i: 24000/30000] loss: 0.4966 rate: 46.5 elapsed: 0.17 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:09:36 - [i: 25000/30000] loss: 0.4911 rate: 46.5 elapsed: 0.17 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:09:58 - [i: 26000/30000] loss: 0.4898 rate: 46.5 elapsed: 0.18 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:10:20 - [i: 27000/30000] loss: 0.4837 rate: 45.4 elapsed: 0.18 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:10:42 - [i: 28000/30000] loss: 0.5848 rate: 45.3 elapsed: 0.19 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:11:05 - [i: 29000/30000] loss: 0.4836 rate: 42.8 elapsed: 0.20 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:11:26 - [i: 30000/30000] loss: 0.4780 rate: 47.1 elapsed: 0.20 hr PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_
# [INFO] 2024-03-26 11:11:26 - [i: 30000/30000] Training complete
# {'static': {'domain': {'xd': 2,
#    'corners': Array([[0.   , 0.   ],
#           [0.   , 0.044],
#           [0.048, 0.06 ],
#           [0.048, 0.044]], dtype=float32)},
#   'problem': {'dims': (5, 2),
#    'E': Array([[[[14.,  0.],
#             [ 0.,  4.]],
#
#            [[ 0.,  5.],
#             [ 5.,  0.]]],
#
#
#           [[[ 0.,  5.],
#             [ 5.,  0.]],
#
#            [[ 4.,  0.],
#             [ 0., 14.]]]], dtype=float32),
#    'nbc_points_right': 200,
#    'nbc_points_top': 200,
#    'nbc_points_bottom': 200,
#    'dbc_points_left': 200,
#    'sd': 0.1,
#    'lambda_true': 4,
#    'mu_true': 5}},
#  'trainable': {'network': {'subdomain': {'layers': [(Array([[-0.3744086 , -1.1132727 ],
#              [ 0.21629477,  1.1886137 ],
#              [-1.1240919 ,  1.1336932 ],
#              [-0.49744886, -0.5862488 ],
#              [ 1.3986503 ,  2.3521078 ],
#              [ 0.85144794,  0.9393237 ],
#              [ 1.0337098 ,  1.1497898 ],
#              [ 0.6966283 , -0.45023626],
#              [-1.9188038 , -0.05660338],
#              [-0.9109736 ,  0.24347891],
#              [ 0.03566329, -0.05813596],
#              [-1.8920828 ,  0.42714515],
#              [-1.3173355 ,  1.180586  ],
#              [-0.9031167 ,  0.20881064],
#              [-3.6485045 , -1.3764507 ],
#              [ 2.7158604 , -0.12991267]], dtype=float32),
#       Array([-0.19000117, -0.516095  ,  0.32247022,  0.2529367 , -0.5977947 ,
#               0.34183416,  0.34768844,  0.54147226,  0.05958286,  0.31219223,
#              -0.5586935 ,  0.4961495 ,  0.25539413, -0.36355424,  0.07173997,
#              -0.10441443], dtype=float32)),
#      (Array([[-1.62392125e-01, -3.30389440e-01,  5.67703396e-02,
#                1.17959172e-01, -5.18595457e-01, -1.61166266e-01,
#                3.38957575e-03, -3.67855802e-02, -1.08954832e-01,
#               -1.21207605e-03,  2.55130492e-02, -8.09965730e-02,
#               -2.75228143e-01,  3.30865473e-01,  1.98511750e-01,
#               -6.66620117e-03],
#              [-1.10977493e-01,  2.68340766e-01,  1.66903794e-01,
#               -3.03840730e-02,  5.68716705e-01,  2.39255905e-01,
#                1.46883950e-01,  1.70716330e-01, -2.18440950e-01,
#                1.59289449e-01,  3.57963532e-01,  1.32335615e+00,
#                1.56619355e-01],
#              [-2.79080570e-01, -5.13334930e-01, -6.30204752e-02,
#               -1.81481138e-01,  3.67710352e-01,  1.79149306e+00,
#               -9.26735103e-01,  6.38999268e-02, -8.10306430e-01,
#               -7.19409049e-01,  6.82685152e-02, -2.49708429e-01,
#                4.39109683e-01,  2.23926399e-02,  1.49167442e+00,
#               -3.95960063e-01],
#              [-4.96504593e+00, -1.86980617e+00, -4.01214409e+00,
#                5.13467550e+00, -8.83865738e+00,  1.27684712e+00,
#               -4.99737352e-01,  2.17298913e+00,  2.09026694e+00,
#               -2.40939736e+00, -2.02501631e+00,  1.60748696e+00,
#               -3.90184546e+00,  2.43391061e+00,  7.93952942e-01,
#                1.81203091e+00]], dtype=float32),
#       Array([-0.2561219 ,  0.06716114, -0.23815002,  0.55008286, -2.0155468 ],      dtype=float32))]}}}}

# %%
from FBPINNsModel.plot import load_FBPINN, load_PINN, exact_solution
from fbpinns.analysis import load_model

c, model = load_model(run, rootdir="results/")

# Test model
from fbpinns.analysis import FBPINN_solution, PINN_solution
i, all_params, all_opt_states, u_test_losses = model
x_batch_test = domain.sample_interior(all_params=all_params, key=None, sampler="grid", batch_shape=(500,500))
out = PINN_solution(c, all_params, x_batch_test)

ux_test, uy_test, sigaxx_test, sigmayy_test, sigmaxy_test  = out[:,0:1],out[:,1:2],out[:,2:3],out[:,3:4],out[:,4:5]
# Out:
# [INFO] 2024-03-26 11:11:27 - Loading model from:
# results/models/PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_/model_00030000.jax
# [INFO] 2024-03-26 11:11:27 - x_batch
# [INFO] 2024-03-26 11:11:27 - (250000, 2), float32, ArrayImpl

# %%
from CooksMembrane.util import plot_deformation

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6), dpi=300)
plot_deformation(ux_test, x_batch_test,ax1,"ux")
plot_deformation(uy_test, x_batch_test,ax2,"uy")
plt.tight_layout()
plt.show()

# %%
from fbpinns.analysis import FBPINN_solution, PINN_solution
from fbpinns.analysis import load_model

c, model = load_model(run, rootdir="results/")
all_params, domain = model[1], c.domain

x_batch_test = FEM[['x', 'y']].values
out_pinn = PINN_solution(c, all_params, x_batch_test)

ux_pinn, uy_pinn, sigaxx_pinn, sigmayy_pinn, sigmaxy_pinn  = out_pinn[:,0:1],out_pinn[:,1:2],out_pinn[:,2:3],out_pinn[:,3:4],out_pinn[:,4:5]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6), dpi=300)
plot_deformation( FEM["ux"],FEM[['x', 'y']].values, ax1, "FEM ux", 16)
plot_deformation(ux_pinn, x_batch_test, ax2, set_title="PINN ux", point_size=16)
# Out:
# [INFO] 2024-03-26 11:11:40 - Loading model from:
# results/models/PINN_adaptive_CooksProblemForwardHardVersion2_FCN_(30, 30)-nCol_30000-epochs_1-layers_16-hidden_1.6_wo_/model_00030000.jax
# [INFO] 2024-03-26 11:11:40 - x_batch
# [INFO] 2024-03-26 11:11:40 - (121, 2), float64, ndarray

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6), dpi=300)
plot_deformation( FEM["uy"],FEM[['x', 'y']].values, ax1, "FEM uy", 16)
plot_deformation(uy_pinn, x_batch_test, ax2, set_title="PINN uy", point_size=16)
